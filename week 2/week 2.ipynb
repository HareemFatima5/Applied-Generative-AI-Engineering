# %% [markdown]
# ### **Importing libraries**

# %%
# !pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.30.3)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.197.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.47.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.6)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.12.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.28.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.81.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.3.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (2026.5.20)

# %%
import google.generativeai as genai
import getpass

API_key = getpass.getpass("Enter your api here:")
genai.configure(api_key=API_key)
model=genai.GenerativeModel("gemini-3.1-flash-lite-preview")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# Enter your api here:··········

# %% [markdown]
# ### **Zero-Shot Prompting**
#
# We want AI to answer without giving it any examples

# %% [markdown]
# ### **Example 1**

# %%
prompt="""Translate this sentence to Urdu
Sentence: I am learning AI"""

response = model.generate_content(prompt)
print("Zero shot prompting")
print(response.text)
# Out:
# Zero shot prompting
# You can translate "I am learning AI" into Urdu in a few ways:
#
# 1. **میں اے آئی (AI) سیکھ رہا ہوں۔** (If you are male)
# 2. **میں اے آئی (AI) سیکھ رہی ہوں۔** (If you are female)
#
# **Breakdown:**
# * **میں (Main):** I
# * **سیکھ رہا ہوں/رہی ہوں (Seekh raha hoon/rahi hoon):** am learning
# * **اے آئی (AI):** AI (It is common to use the English abbreviation in Urdu).

# %% [markdown]
# ### **Example 2**

# %%
prompt="""Classify this review as Positive or Negative:
'The product was amazing and delivery was fast."""

response = model.generate_content(prompt)
print("Zero shot prompting")
print(response.text)
# Out:
# Zero shot prompting
# Positive

# %% [markdown]
# ### **Example 3**

# %%
prompt="""Summarize this paragraph
Reading books is an incredibly rewarding habit that broadens our horizons and sharpens our minds."""

response = model.generate_content(prompt)
print("Zero shot prompting")
print(response.text)
# Out:
# Zero shot prompting
# Reading books expands our knowledge and improves cognitive function.

# %% [markdown]
# ### **Few-Shot Prompting**
#
# We give model some examples so it unerstand what user wants

# %% [markdown]
# ### **Example 1**

# %%
prompt = """Here are some examples of sentiment classification:

Review: "The food was delicious and the staff was so friendly!" = Positive
Review: "Waited 2 hours and the food was cold. Never again." = Negative
Review: "It was fine, nothing too special about it." = Neutral

Now classify this:
Review: "Honestly the best coffee I have ever had in my life!" ="""

response = model.generate_content(prompt)
print("Output:", response.text)
# Out:
# Output: Positive

# %% [markdown]
# ### **Example 2**

# %%
prompt = """Look at these emails and their categories:

Email: "URGENT: Server is down, please fix immediately!" = Urgent
Email: "Hey, are we still on for lunch tomorrow?" = Normal
Email: "Congratulations! You won a free iPhone. Click here." = Spam

Now classify this:
Email: "Please review and approve the report before 5pm today." ="""

response = model.generate_content(prompt)
print("Output:", response.text)
# Out:
# Output: Email: "Please review and approve the report before 5pm today." = Urgent

# %% [markdown]
# ### **Example 3**

# %%
prompt = """Here are some job titles and their departments:

Job Title: "Surgeon" = Department: Healthcare
Job Title: "Software Engineer" = Department: Technology
Job Title: "Chartered Accountant" = Department: Finance

Now classify this:
Job Title: "Data Scientist" ="""

response = model.generate_content(prompt)
print("Output:", response.text)
# Out:
# Output: Department: Technology

# %% [markdown]
# ### **Role-Based Prompting**
#
# We assign the model a role so it acts accordingly

# %% [markdown]
# ### **Example 1**

# %%
prompt = """You are a Python teacher who has been teaching beginners for 10 years.One of your students does not understand what a loop is.
Explain what a for loop is in Python using a very simple real life example. Then show a basic code example."""

response = model.generate_content(prompt)
print("Output:", response.text)
# Out:
# Output: Hello there! It’s great to see you. Don’t worry at all—most of my students struggle with the concept of a "loop" at first. But once you see it in the real world, it’s actually quite simple.
#
# ### The Real-Life Example: The Mailbox
# Imagine you have a stack of 10 envelopes on your desk that need to be mailed.
#
# If you were a computer without a loop, you would have to write out instructions for every single one:
# 1. Pick up envelope #1, stamp it, and put it in the bag.
# 2. Pick up envelope #2, stamp it, and put it in the bag.
# 3. Pick up envelope #3, stamp it, and put it in the bag...
# ...and so on until #10. That is tedious and repetitive!
#
# **A loop** is like giving yourself one simple instruction:
# *"For every envelope in this stack, stamp it and put it in the bag."*
#
# You don't care if there are 10 envelopes or 100; you just repeat that same action until the stack is empty. You’ve just performed a loop!
#
# ***
#
# ### The Python Code
# In Python, we use the `for` keyword to do exactly that. We take a collection of items (like our stack of envelopes) and tell Python to perform an action for each one.
#
# Here is how you would write that in code:
#
# ```python
# # Here is our "stack" of envelopes
# envelopes = ["Envelope 1", "Envelope 2", "Envelope 3", "Envelope 4", "Envelope 5"]
#
# # This is the loop:
# # "for every item in the stack, do this action"
# for envelope in envelopes:
#     print("I am stamping " + envelope)
#
# print("All done!")
# ```
#
# ### What is happening here?
# 1. **`envelopes`**: This is our list (the stack on your desk).
# 2. **`for envelope in envelopes:`**: This tells Python to look at the list, grab the first item, and call it `envelope`. It then runs the code inside the loop.
# 3. **The indented code (`print...`)**: This is the action you perform on each item.
# 4. **Repeating**: Once Python finishes that line, it goes back to the top, grabs the *next* item from the list, and runs the same code again. It does this automatically until there are no items left.
#
# Does that help make the concept feel a little less "robotic"? Think of the loop as your way of being efficient—you’re telling the computer to handle the repetition so you don't have to!

# %% [markdown]
# ### **Example 2**

# %%
prompt = """You are an experienced doctor who explains medical conditions in very simple language for patients who have no medical background.
Explain what diabetes is, what causes it, and what a patient should avoid eating. Keep it simple and friendly."""

response = model.generate_content(prompt)
print("Output:", response.text)
# Out:
# Output: Hello! It’s great that you’re asking these questions. I’m happy to help you understand this. Think of me as your partner in health—let’s break this down into plain, simple language.
#
# ### What is diabetes?
# Think of your body like a car and the food you eat like fuel. When you eat, your body turns that food into a type of sugar called **glucose**, which travels through your blood to give your cells energy.
#
# To get that sugar out of your blood and into your cells, your body uses a "key" called **insulin**.
#
# In someone with diabetes, one of two things happens:
# 1. Your body stops making enough keys (insulin).
# 2. The locks on your cells get jammed, so the keys don't work anymore.
#
# Because the sugar can't get into your cells to be used as energy, it just sits in your blood. That’s why we say you have "high blood sugar."
#
# ### What causes it?
# It’s usually a mix of things, and it’s important to know that **it’s not your fault.**
#
# *   **Genetics:** Sometimes it just runs in the family. If your parents or siblings have it, you might be more likely to get it.
# *   **Weight and Activity:** Carrying extra weight, especially around the belly, can make it harder for your body’s "locks" to work properly. Not moving much makes it harder for your body to process that sugar.
# *   **Age and Biology:** As we get older, our bodies naturally change, and sometimes our pancreas (the organ that makes the insulin) gets a little tired.
#
# ### What should you avoid eating?
# The goal isn’t to stop eating—it’s to stop the "sugar spikes." Think of some foods like a gentle uphill slope for your blood sugar, and others like a rocket ship. We want to avoid the rocket ships.
#
# **Foods to limit (The "Rocket Ships"):**
# *   **Sugary Drinks:** Soda, sweetened teas, energy drinks, and fruit juices. These are the fastest way to spike your blood sugar.
# *   **White Starches:** White bread, white rice, white pasta, and flour tortillas. These turn into sugar in your blood almost as fast as candy does.
# *   **Processed Snacks:** Chips, crackers, and store-bought cookies. These often have hidden sugars and unhealthy fats.
# *   **Sweet Treats:** Candy, cake, ice cream, and pastries. Enjoy these only as very occasional, small treats—not as part of your daily routine.
#
# **What to embrace instead:**
# *   **Fiber-rich foods:** Think brown rice, oats, beans, and lentils. They release energy slowly, so you don't get that "crash."
# *   **Vegetables:** Almost all non-starchy veggies (like broccoli, spinach, peppers, and cucumbers) are your best friends.
# *   **Lean Proteins:** Chicken, fish, eggs, and tofu help you feel full without spiking your blood sugar.
#
# ### My best advice for you:
# You don't have to be perfect overnight. The best approach is **"The Plate Method."** When you sit down for dinner, imagine your plate is a clock:
# *   **Half of the plate** should be colorful vegetables.
# *   **One-quarter** should be a lean protein (like chicken or fish).
# *   **One-quarter** should be a complex carbohydrate (like brown rice or a small potato).
#
# If you focus on that, you’re already doing a fantastic job. Do you have any other questions about how this works? I'm here to help!

# %% [markdown]
# ### **Example 3**

# %%
prompt = """You are a senior hiring manager at a top tech company.
You are interviewing a fresh computer science graduate for a junior data science position.
Ask them 5 interview questions, one by one, starting from easy and getting harder."""

response = model.generate_content(prompt)
print("Output:", response.text)
# Out:
# Output: It’s a pleasure to meet you. We are looking for someone who not only has the technical foundation but also the curiosity to solve real-world problems with data. We’ll go through five questions, moving from the basics of data handling to more complex conceptual challenges.
#
# Let’s start with the first one.
#
# **Question 1 (Easy):**
# In a typical data science project, you’ll often find that your raw dataset contains missing values. Can you explain the difference between **dropping** rows with missing data versus **imputing** them, and how would you decide which approach to take for a specific feature?

# %% [markdown]
# ### **Output constraints**
#
# We add some rules so model answers accordingly

# %% [markdown]
# ### **Example 1**

# %%
prompt = """List 5 benefits of drinking water daily.
Rules you must follow:
1) Use bullet points only
2) Each point must be under 10 words
3) Do not number the points"""

response = model.generate_content(prompt)
print("Output:", response.text)
# Out:
# Output: * Improves physical performance
# * Boosts brain function and focus
# * Aids in healthy digestion
# * Helps maintain skin health
# * Regulates body temperature effectively

# %% [markdown]
# ### **Example 2**

# %%
prompt = """Explain artificial intelligence in exactly 50 words not more, not less.
Use simple language that a 10 year old can understand.Do not use any technical terms."""

response = model.generate_content(prompt)
print("Output:", response.text)
# Out:
# Output: Artificial intelligence is when computers learn to think and act like people. By looking at lots of information, they figure out how to solve problems, recognize pictures, or answer your questions. It is like teaching a machine to use its brain to help you do things faster and much better.

# %% [markdown]
# ### **Example 3**

# %%
prompt = """Give me information about Python programming language.
You must follow this exact format and no other:
Name:
Created In:
Created By:
Main Use:
Do not add anything outside this format."""

response = model.generate_content(prompt)
print("Output:", response.text)
# Out:
# Output: Name: Python
# Created In: 1991
# Created By: Guido van Rossum
# Main Use: Data science, web development, and automation

# %% [markdown]
# ### **Summarization**
# We ask the model to summarize text

# %% [markdown]
# ### **Example 1**

# %%
text = """Artificial intelligence is transforming industries worldwide. From healthcare to finance, AI systems are being used to analyze large amounts of data, detect
patterns, and make predictions. In healthcare, AI helps doctors diagnose diseases earlier and more accurately. In finance, it detects fraud and manages risk. However, AI also raises concerns about
job displacement and privacy."""

prompt = "Summarize the text below in exactly 2 sentences. Keep it simple for a general audience.\n\nText: " + text

response = model.generate_content(prompt)
print("Output:")
print(response.text)
# Out:
# Output:
# Artificial intelligence is revolutionizing various sectors by analyzing data to improve medical diagnoses and financial security. While these advancements offer significant benefits, they also create important challenges regarding personal privacy and the future of jobs.

# %% [markdown]
# ### **Example 2**

# %%
text = """The government announced a new policy today aimed at reducing plastic waste across the country. Under the new rules, single use plastic bags will be
banned starting next year, and businesses will be encouraged to switch to biodegradable packaging. Officials say this step is part of a larger plan to tackle pollution and protect the environment."""

prompt = "Summarize the text below in exactly 1 sentence.\n\nText: " + text

response = model.generate_content(prompt)
print("Output:")
print(response.text)
# Out:
# Output:
# The government has announced a new policy to combat pollution by banning single-use plastic bags next year and promoting the use of biodegradable packaging.

# %% [markdown]
# ### **Example 3**

# %%
text = """Our quarterly sales report shows a 15% increase in revenue compared to last quarter, driven mainly by strong performance in the online segment. However,
in-store sales dropped by 5% due to reduced foot traffic. The marketing team recommends increasing the digital ad budget for next quarter while reviewing the in-store experience to identify the cause of the decline."""

prompt = "You are summarizing this report for a busy manager who only has 30 seconds to read it. Summarize in 3 short bullet points, no more.\n\nText: " + text

response = model.generate_content(prompt)
print("Output:")
print(response.text)
# Out:
# Output:
# Here is the summary:
#
# * **Revenue is up 15%:** Growth is primarily driven by strong online sales.
# * **In-store decline:** Physical store revenue dropped 5% due to lower foot traffic.
# * **Next steps:** We will increase digital ad spend and investigate the root cause of the in-store decline.

# %% [markdown]
# ### **Classification**
# we ask the model to classify into categories

# %% [markdown]
# ### **Example 1**

# %%
prompt = """Classify each customer complaint into one of these categories:
Delivery,Customer Service, Billing
Complaints:
1. "My order arrived 2 weeks late."
2. "I was charged twice for one order."
3. "The support agent was very rude."
Format:
Complaint 1: [Category]
Complaint 2: [Category]
Complaint 3: [Category]"""

response = model.generate_content(prompt)
print("Output:")
print(response.text)
# Out:
# Output:
# Complaint 1: Delivery
# Complaint 2: Billing
# Complaint 3: Customer Service

# %% [markdown]
# ### **Example 2**

# %%
prompt = """Classify each movie description into one genre:
Action, Comedy, Horror, Romance
Descriptions:
1. "A group of friends fight off zombies in an abandoned mall."
2. "A clumsy office worker keeps causing hilarious chaos at work."
3. "A spy must stop a bomb from going off in the city."

Format:
Description 1: [Genre]
Description 2: [Genre]
Description 3: [Genre]"""

response = model.generate_content(prompt)
print("Output:")
print(response.text)
# Out:
# Output:
# Description 1: Horror
# Description 2: Comedy
# Description 3: Action

# %% [markdown]
# ### **Example 3**

# %%
prompt = """Classify each piece of student feedback as Positive, Negative, or Mixed.
Feedback:
1. "The teacher explained everything so clearly, I loved this class."
2. "The lectures were too fast and I could not keep up."
3. "Good content but the assignments were way too difficult."

Format:
Feedback 1: [Classification]
Feedback 2: [Classification]
Feedback 3: [Classification]"""

response = model.generate_content(prompt)
print("Output:")
print(response.text)
# Out:
# Output:
# Feedback 1: Positive
# Feedback 2: Negative
# Feedback 3: Mixed

# %% [markdown]
# ### **Extraction**
#
# we ask the model to extract information from text

# %% [markdown]
# ### **Example 1**

# %%
text = "Elon Musk announced on Monday that Tesla will open a new factory in Berlin by March 2026."

prompt = "Extract the following from the text below:\n- Person Names\n- Company Names\n- Locations\n- Dates\n\nPresent each as a separate bullet list.\n\nText: " + text

response = model.generate_content(prompt)
print("Output:")
print(response.text)
# Out:
# Output:
# Here is the information extracted from the text:
#
# **Person Names**
# * Elon Musk
#
# **Company Names**
# * Tesla
#
# **Locations**
# * Berlin
#
# **Dates**
# * Monday
# * March 2026

# %% [markdown]
# ### **Example 2**

# %%
text = "My name is Sara Ahmed. You can reach me at sara.ahmed@email.com or call me at 0300-1234567. I work at TechSoft Solutions."

prompt = "Extract the following from the text below:\n- Name\n- Email\n- Phone Number\n- Company Name\n\nPresent each as a separate line.\n\nText: " + text

response = model.generate_content(prompt)
print("Output:")
print(response.text)
# Out:
# Output:
# Name: Sara Ahmed
# Email: sara.ahmed@email.com
# Phone Number: 0300-1234567
# Company Name: TechSoft Solutions

# %% [markdown]
# ### **Example 3**

# %%
text = """Machine learning is a subset of artificial intelligence that enables systems to learn from data and improve their performance without being explicitly programmed. It is widely used in image recognition,
natural language processing, and recommendation systems."""

prompt = "Extract exactly 5 keywords from the text below. These should represent the main topics. Return them as a numbered list, most important first.\n\nText: " + text

response = model.generate_content(prompt)
print("Output:")
print(response.text)
# Out:
# Output:
# 1. Machine learning
# 2. Artificial intelligence
# 3. Data
# 4. Image recognition
# 5. Natural language processing
